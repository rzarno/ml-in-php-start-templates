# %%
import pandas as pd

df = pd.read_csv('sales_processed.csv')

# %%
df
# Out:
#         id   sales  day  year  day_week  month  is_holiday  prev_week  \
# 0        1  287686    1  2019         1      1           1          0
# 1        2  346366    2  2019         2      1           0     287686
# 2        3  297816    3  2019         3      1           0     634052
# 3        4  302926    4  2019         4      1           0     931868
# 4        5  197438    5  2019         5      1           0    1234794
# ...    ...     ...  ...   ...       ...    ...         ...        ...
# 1090  1091  282088   26  2021         6     12           0    2165441
# 1091  1092  233980   27  2021         0     12           0    2216660
# 1092  1093  360223   28  2021         1     12           0    1999576
# 1093  1094  311690   29  2021         2     12           0    1735866
# 1094  1095  543399   30  2021         3     12           0    1639446
#
#       prev_year
# 0        287686
# 1        346366
# 2        297816
# 3        302926
# 4        197438
# ...         ...
# ...

# %%
df2 = pd.read_csv('predictions.csv')

# %%
df3 = pd.DataFrame()
df3['real'] = df['sales']
df3['predicted'] = df2['sales']
df3.loc[450:500].plot(figsize=(40, 10))
# Out:
# <AxesSubplot:>
